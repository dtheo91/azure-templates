# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join("..")))
from config import config
from modules.azure_foundry.azure_foundry_client import AzureFoundryClient

# %% [markdown]
# ### Get Foundry Client

# %%
foundry = AzureFoundryClient(user_endpoint=config.user_endpoint)

# %% [markdown]
# ### Get Agent by Name

# %%
agent = foundry.project_client.agents.get(agent_name="testagent")

# %% [markdown]
# ### Call Agent

# %%
response = foundry.openai_client.responses.create(
    input=[{"role": "user", "content": "Tell me a one line story"}],
    extra_body={"agent": {"name": agent.name, "type": "agent_reference"}},
)

print(f"Response output: {response.output_text}")
# Out:
# Response output: On the morning the city forgot how to dream, a boy taught the pigeons to hum lullabies until the buildings remembered how to sleep.
